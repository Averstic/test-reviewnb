# %% [markdown]
# # Extract orthology data from OMA API

# %% [markdown]
# ## 1. Install

# %%
# %%bash
#
# pip install coreapi
# Out:
# Collecting coreapi
#   Using cached coreapi-2.3.3-py2.py3-none-any.whl (25 kB)
# Collecting uritemplate
#   Using cached uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: requests in /home/averstichele/.minconda3/envs/PATHF_chromatin_tracks_analysis/lib/python3.7/site-packages (from coreapi) (2.25.0)
# Collecting coreschema
#   Downloading coreschema-0.0.4.tar.gz (10 kB)
# Collecting itypes
#   Using cached itypes-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/averstichele/.minconda3/envs/PATHF_chromatin_tracks_analysis/lib/python3.7/site-packages (from requests->coreapi) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/averstichele/.minconda3/envs/PATHF_chromatin_tracks_analysis/lib/python3.7/site-packages (from requests->coreapi) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/averstichele/.minconda3/envs/PATHF_chromatin_tracks_analysis/lib/python3.7/site-packages (from requests->coreapi) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/averstichele/.minconda3/envs/PATHF_chromatin_tracks_analysis/lib/python3.7/site-packages (from requests->coreapi) (3.0.4)
# Requirement already satisfied: jinja2 in /home/averstichele/.minconda3/envs/PATHF_chromatin_tracks_analysis/lib/python3.7/site-packages (from coreschema->coreapi) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/averstichele/.minconda3/envs/PATHF_chromatin_tracks_analysis/lib/python3.7/site-packages (from jinja2->coreschema->coreapi) (1.1.1)
# Building wheels for collected packages: coreschema
#   Building wheel for coreschema (setup.py): started
#   Building wheel for coreschema (setup.py): finished with status 'done'
#   Created wheel for coreschema: filename=coreschema-0.0.4-py3-none-any.whl size=15032 sha256=3fea0c641b099c36beaeef92e36c8bcc34a1500b2b43733ccd6d4ceee6607c1c
#   Stored in directory: /home/averstichele/.cache/pip/wheels/29/28/77/73539fe0ce161da7a571cd8278a9296adbda257406bb6f100d
# Successfully built coreschema
# Installing collected packages: uritemplate, coreschema, itypes, coreapi
# Successfully installed coreapi-2.3.3 coreschema-0.0.4 itypes-1.2.0 uritemplate-3.0.1

# %% [markdown]
# ## 2. Initiate

# %%
import pandas as pd
from coreapi import Client

client=Client()
document=client.get('https://omabrowser.org/api/docs')

# %% [markdown]
# ## 3. Extract orthologs

# %%
SPECIES='MAIZE'
IDs=['AT3G52180','AT4G30500','AT4G35500']

data=[]
for ID in IDs:
    d=pd.DataFrame(client.action(document, ['protein','orthologs'],params={"entry_id":ID}))
    d['query']=ID
    data.append(d)
data=pd.concat(data)

# %% [markdown]
# ## 4. Filter species

# %%
data_species=data[data['species'].astype(str).str.contains(SPECIES)]

# %%
data_species
# Out:
#      entry_nr                                     entry_url       omaid  \
# 8    14062166  https://omabrowser.org/api/protein/14062166/  MAIZE07161
# 198  14104078  https://omabrowser.org/api/protein/14104078/  MAIZE49073
# 354  14085265  https://omabrowser.org/api/protein/14085265/  MAIZE30260
#
#     canonicalid                      sequence_md5  sequence_length  \
# 8        B4FJN0  7be3b373a02b396706e8ecb752408b14              373
# 198      B4FPU6  96c0ee664185c8b448bdb61716ef6cd1              174
# 354      B4G1A4  4fdb909eabc33759c3f06dfac451fd9b              424
#
#                                                species  oma_group  \
# 8    {'code': 'MAIZE', 'taxon_id': 4577, 'species':...     522474
# 198  {'code': 'MAIZE', 'taxon_id': 4577, 'species':...     910085
# 354  {'code': 'MAIZE', 'taxon_id': 4577, 'species':...     598285
#
#                   oma_hog_id chromosome  \
# 8                HOG:0212555          1
# 198              HOG:0513146          4
# 354  HOG:0500414.12ffv.3775b          2
#
#                                                  locus  is_main_isoform  \
# 8     {'start': 2629741, 'end': 2635693, 'strand': -1}             True
# 198  {'start': 157331300, 'end': 157334121, 'strand...             True
# 354  {'start': 204222660, 'end': 204225399, 'strand...             True
#
#     rel_type   distance        score      query
# 8        1:1  35.335701  1579.349976  AT3G52180
# 198      m:1  46.000000  1020.169983  AT4G30500
# 354      m:1  38.582901  2778.570068  AT4G35500

# %% [markdown]
# ## 4. Cross reference

# %%
xref=[]
for omaid,query in zip(data_species['omaid'],data_species['query']):
    x=pd.DataFrame(client.action(document, ['protein','xref'],params={"entry_id":omaid}))[['xref']]
    x.columns=[query]
    xref.append(x)
pd.concat(xref,axis=1)
# Out:
#                                        AT3G52180                  AT4G30500  \
# 0                                     A0A317Y671                 A0A3L6F0X9
# 1                                         B4FJN0                     B4FPU6
# 2                                   NP_001136639               XP_008676505
# 3                                   XP_008665116                  100192887
# 4                                      100216768             Zm00001d051405
# 5                                 Zm00001d027309        Zm00001d051405_P001
# 6                            Zm00001d027309_P005        Zm00001d051405_T001
# 7                            Zm00001d027309_T005             Zm00001d051405
# 8                                 Zm00001d027309        Zm00001d051405_P001
# 9                            Zm00001d027309_P005        Zm00001d051405_T001
# 10                           Zm00001d027309_T005                  100192887
# 11                                     100216768                    tmem208
# 12  Phosphoglucan phosphatase DSP4 chloroplastic      Transmembrane protein
# 13  Phosphoglucan phosphatase DSP4, amyloplastic  Transmembrane protein 208
# 14                       ZEAMMB73_Zm00001d027309    ZEAMMB73_Zm00001d051405
# 15                               Zm00014a_042139            Zm00014a_009616
# 16                        4577.GRMZM2G052546_P03     4577.GRMZM2G046348_P02
#
#                                AT4G35500
# 0                             A0A3L6FVC6
# 1                                 B4G1A4
# 2                           NP_001142305
# 3                              100274474
# 4                         Zm00001d006308
# 5                    Zm00001d006308_P001
# 6                    Zm00001d006308_T001
# 7                         Zm00001d006308
# 8                    Zm00001d006308_P001
# 9                    Zm00001d006308_T001
# 10                             100274474
# 11                                SRPK_1
# 12    Protein kinase superfamily protein
# 13  Serine/threonine-protein kinase SRPK
# 14               ZEAMMB73_Zm00001d006308
# 15                       Zm00014a_038172
# 16                4577.AC233910.1_FGP010
